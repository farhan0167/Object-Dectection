# %% [markdown]
# <a href="https://colab.research.google.com/github/farhan0167/Object-Dectection/blob/main/BEIT-DETR-Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q git+https://github.com/huggingface/transformers.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 84 kB 2.3 MB/s
#      |████████████████████████████████| 6.6 MB 22.3 MB/s
#      |████████████████████████████████| 596 kB 50.1 MB/s
# ...

# %%
from transformers import BeitModel, BeitConfig,BeitFeatureExtractor, BeitForImageClassification

# %% [markdown]
# ## To access the Repository
#
# In order to access my files, I have shared a google [drive](https://drive.google.com/drive/folders/1xh0DK0IgdCQqOWVY39mRjsqcnnlO2gox?usp=sharing) folder. Make a copy of this in your own drive. Mount your drive and go to the folder.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/mightydetr/detr
# Out:
# /content/drive/MyDrive/mightydetr/detr

# %% [markdown]
# ## Training

# %%
# !python -m torch.distributed.launch --use_env main.py --dataset_file face --batch_size 1 --epochs 10 --data_path /content/drive/MyDrive/mightydetr/dataset/ --output_dir outputs2
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: [6]  [1160/9977]  eta: 0:14:47  lr: 0.000100  class_error: 100.00  loss: 2.4207 (3.0330)  loss_ce: 0.3631 (0.4889)  loss_bbox: 0.6992 (0.9822)  loss_giou: 1.2191 (1.5620)  loss_ce_unscaled: 0.3631 (0.4889)  class_error_unscaled: 100.0000 (100.0000)  loss_bbox_unscaled: 0.1398 (0.1964)  loss_giou_unscaled: 0.6096 (0.7810)  cardinality_error_unscaled: 1.0000 (2.6081)  time: 0.0999  data: 0.0070  max mem: 2346
# Epoch: [6]  [1170/9977]  eta: 0:14:46  lr: 0.000100  class_error: 100.00  loss: 2.8019 (3.0360)  loss_ce: 0.4725 (0.4896)  loss_bbox: 0.6992 (0.9822)  loss_giou: 1.6418 (1.5642)  loss_ce_unscaled: 0.4725 (0.4896)  class_error_unscaled: 100.0000 (100.0000)  loss_bbox_unscaled: 0.1398 (0.1964)  loss_giou_unscaled: 0.8209 (0.7821)  cardinality_error_unscaled: 2.0000 (2.6123)  time: 0.1014  data: 0.0068  max mem: 2346
# ...
